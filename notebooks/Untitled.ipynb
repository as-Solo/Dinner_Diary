# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
import sys
import sqlalchemy as alch
from datetime import date
from datetime import datetime

sys.path.append("../")
load_dotenv()
# Out:
# True

# %%
tok1 = os.getenv('Client_Id')
tok2 = os.getenv('Client_Secret')
tok3 = os.getenv('SQL')

# %%
connectionData = f'mysql+pymysql://root:{tok3}@localhost/diary'
engine = alch.create_engine(connectionData)

# %%
nombres = engine.execute('''
SELECT latitud, longitud
FROM restaurantes
''')
lista = nombres.fetchall()

# %%
datos = engine.execute('''
SELECT column_name, data_type 
FROM information_schema.columns 
WHERE table_name = 'restaurantes' AND (column_name = 'latitud' OR column_name = 'longitude');
''')
datos.fetchall()
# Out:
# [('latitud', 'varchar')]

# %%
etiquetas = engine.execute('''
SELECT etiqueta
FROM etiquetas
''')
lista_e = etiquetas.fetchall()
lista_e
# Out:
# [('American',),
#  ('Arepas',),
#  ('Argentinian',),
#  ('Art Gallery',),
#  ('Art Museum',),
#  ('Arts & Crafts',),
#  ('Asian',),
#  ('Bakery',),
#  ('Bar',),
#  ('Basketball Court',),
#  ('BBQ',),
#  ('Beach',),
#  ('Beer Bar',),
#  ('Beer Garden',),
#  ('Big Box Store',),
#  ('Bistro',),
#  ('Bookstore',),
#  ('Boutique',),
#  ('Boxing Gym',),
#  ('Breakfast',),
#  ('Brewery',),
#  ('Bridge',),
#  ('Burgers',),
#  ('Café',),
#  ('Cafeteria',),
#  ('Candy Store',),
#  ('Casino',),
#  ('Caucasian',),
#  ('Chinese',),
#  ('Chocolate Shop',),
#  ('Cineplex',),
#  ('Circus',),
#  ('Cocktail',),
#  ('Coffee Shop',),
#  ('Comedy Club',),
#  ('Concert Hall',),
#  ('Cosmetics',),
#  ('Creperie',),
#  ('Cuban',),
#  ('Cupcakes',),
#  ('Dance Studio',),
#  ('Deli / Bodega',),
#  ('Department Store',),
#  ('Desserts',),
#  ('Diner',),
#  ('Dumplings',),
#  ('Electronics',),
#  ('Falafel',),
#  ("Farmer's Market",),
#  ('Fast Food',),
#  ('Flea Market',),
#  ('Food',),
#  ('Food Truck',),
#  ('Football',),
#  ('French',),
#  ('Garden',),
#  ('Gas Station',),
#  ('Gastropub',),
#  ('Gourmet',),
#  ('Greek',),
#  ('Grocery Store',),
#  ('Gym',),
#  ('Gym / Fitness',),
#  ('Hamburguesas',),
#  ('Hawaiian',),
#  ('Historic Site',),
#  ('Hostel',),
#  ('Hotel',),
#  ('Ice Cream',),
#  ('Indian',),
#  ('Indie Movies',),
#  ('Italian',),
#  ('Japanese',),
#  ('Kebab',),
#  ('Korean',),
#  ('Landmark',),
#  ('Liquor Store',),
#  ('Mall',),
#  ('Market',),
#  ('Mediterranean',),
#  ('Metro',),
#  ('Mexican',),
#  ('Middle Eastern',),
#  ('Modern European',),
#  ('Molecular Gastronomy',),
#  ('Movie Theater',),
#  ('Museum',),
#  ('Music Store',),
#  ('Music Venue',),
#  ('Nightclub',),
#  ('Noodles',),
#  ('North Indian',),
#  ('Office Supplies',),
#  ('Opera House',),
#  ('Optical',),
#  ('Paella',),
#  ('Park',),
#  ('Pastry',),
#  ('Pedestrian Street/Plaza',),
#  ('Performing Arts',),
#  ('Persian',),
#  ('Peruvian',),
#  ('Pie Shop',),
#  ('Pizza',),
#  ('Playground',),
#  ('Plaza',),
#  ('Polish',),
#  ('Pool',),
#  ('Portuguese',),
#  ('Pub',),
#  ('Ramen',),
#  ('Restaurant',),
#  ('Salad',),
#  ('Salon / Barbershop',),
#  ('Sandwiches',),
#  ('Seafood',),
#  ('Shops',),
#  ('Skate Park',),
#  ('Snacks',),
#  ('Soccer',),
#  ('Soccer Field',),
#  ('South American',),
#  ('Souvlaki',),
#  ('Spa',),
#  ('Spanish',),
#  ('Sporting Goods',),
#  ('Steakhouse',),
#  ('Supermarket',),
#  ('Sushi',),
#  ('Tacos',),
#  ('Tapas',),
#  ('Tea Room',),
#  ('Thai',),
#  ('Theater',),
#  ('Tibetan',),
#  ('Train Station',),
#  ('Vegetarian / Vegan',),
#  ('Venezuelan',),
#  ('Vietnamese',),
#  ('Wine Bar',),
#  ('Wings',),
#  ('Yoga Studio',),
#  ('Yogurt',)]

# %%
if nombre_plato != '':

                            if comentario_plato != '':

                                try:
                                    id_restaurante = td.buscar_id_rest(nombre_visitados, direccion_visitados)
                                    {id_restaurante}
                                    if st.button('Comentar plato'):
                                        try:
                                            if nombre_plato != '' and comentario_plato != 0:
                                                try:
                                                    td.add_plato(id_usuario, id_restaurante, nombre_plato, puntuacion_plato, comentario_plato)
                                                except:
                                                    pass
                                            st.success('Comentario añadido satisfactoriamente')



                                        except:
                                            st.warning('Ha ocurrido un error, recuerda que los comentarios no pueden ser idénticos')
                                except:
                                    st.warning('El nombre del restaurante y la dirección no coinciden')
                            else:
                                st.warning('Rescuerda que tienes que introducir un dirección para comentar a un restaurante concreto. La tabla te puede ser de ayuda.')
                        
                        else:
                            st.warning('Tienes que introducir un comentario')

# %%
datos = engine.execute('''
        SELECT restaurantes.nombre, restaurantes.latitud, restaurantes.longitud
        
        FROM usuarios
        
        INNER JOIN visitado
        ON visitado.id_usuario = usuarios.id_usuario
        
        INNER JOIN restaurantes
        ON restaurantes.id_rest = visitado.id_rest

        WHERE usuarios.id_usuario = 1
''')
datos
# Out:
# [('Jardines del Prado de San Sebastián', '37.37970096947276', '-5.986969470977783'),
#  ('BIF', '38.745415912891566', '-9.153255584785716')]

# %%
id_usuario = 1

lista = engine.execute(f"""

        SELECT restaurantes.nombre, restaurantes.latitud, restaurantes.longitud
        
        FROM usuarios
        
        INNER JOIN visitado
        ON visitado.id_usuario = usuarios.id_usuario
        
        INNER JOIN restaurantes
        ON restaurantes.id_rest = visitado.id_rest

        WHERE usuarios.id_usuario = {id_usuario}

        """)

lista = lista.fetchall()
lista
# Out:
# [('Jardines del Prado de San Sebastián', '37.37970096947276', '-5.986969470977783'),
#  ('BIF', '38.745415912891566', '-9.153255584785716')]

# %%
diccionario = {'apellidos' : 'No te lo digo',
               
              }

# %%
def atributos_diccionario(nombre, *diccionario):
    apellidos = None
    direccion = None
    codigo_postal = None
    telefono = None
    web = None
    
    try:
        apellidos = diccionario['apellidos']
    except:
        apellidos = None

    try:
        direccion = diccionario['direccion']
    except:
        direccion = None

    try:
        codigo_postal = diccionario['codigo_postal']
    except:
        codigo_postal = None

    try:
        telefono = diccionario['telefono']
    except:
        telefono = None

    try:
        we = diccionario['web']
    except:
        web = None
            
    print (nombre, apellidos, direccion, codigo_postal, telefono, web)

# %%
atributos_diccionario('Alejandro', *diccionario)
# Out:
# Alejandro None None None None None

# %%
def peticion_4s(origen, busqueda, radio = None, masivo = False, limite = 100):
    
    # Defino las variables que voy a necesitar para hacer el proceso. Son como auxiliares.
    url_query = 'https://api.foursquare.com/v2/venues/explore'
    lista_dic = [] #Esto será lo que devuelva.
    estructura = {} # Esta va a ser mi estructura de datos.
    
    # Defino parámetros de búsqueda para four square (el category se carga la fuerza de la query y además no tiene peso sobre el nombre)
    if masivo == True:
        parametros = {
            'categoryId' : '4d4b7105d754a06374d81259',
            'client_id': tok1,
            'client_secret': tok2,
            'v': '20180323',
            'll': origen,
            'query': busqueda, 
            'limit': limite,
            'radius' : radio,    
            }
    else:
         parametros = {
            'client_id': tok1,
            'client_secret': tok2,
            'v': '20180323',
            'll': origen,
            'query': busqueda, 
            'limit': limite,
            'radius' : radio,    
            }

    
    # Hago la petición
    return resp = requests.get(url= url_query, params = parametros).json()

    # La filtro
    data = resp.get("response").get("groups")[0].get("items")
    #return data[0]['venue']['categories'][0]
    
    # Uso esa información para devolver una lista de diccionarios de donde sacar los datos
    for i in range (len(data)):
        dato = data[i]['venue']
        estructura = {'clave' : dato['categories'][0]['id'],
                      'nombre' : dato['name'],
                      'latitud' : dato['location']['lat'],
                      'longitud' : dato['location']['lng'],}      
    # Los datos anteriores están garantizados, los siguientes no, para evitar que se detenga la ejecución hago try
        try:
          estructura['direccion'] = dato['location']['address']
        except:
          estructura['direccion'] = None

        try:
          estructura['distancia'] = dato['location']['distance']
        except:
          estructura['distancia'] = None

        try:
          estructura['postal'] = dato['location']['postalCode']
        except:
          estructura['postal'] = None

        try:
          estructura['acron'] = dato['location']['cc']
        except:
          estructura['acron'] = None

        try:
          estructura['municipio'] = dato['location']['city']
        except:
          estructura['municipio'] = None

        try:
          estructura['ciudad'] = dato['location']['state']
        except:
          estructura['ciudad'] = None

        try:
          estructura['pais'] = dato['location']['country']
        except:
          estructura['pais'] = None

        try:
          estructura['etiqueta'] = dato['categories'][0]['shortName']
        except:
          estructura['etiqueta'] = 'Otros'

        lista_dic.append(estructura)
    
    return resp
# Out:
#   File "<ipython-input-94-4dd1de7fd767>", line 33
#     return resp = requests.get(url= url_query, params = parametros).json()
#                 ^
# SyntaxError: invalid syntax

# %%
lista = peticion_4s('40.39545,-3.71895', 'burguers')
lista
# Out:
# [{'clave': '4bf58dd8d48988d14e941735',
#   'nombre': 'Mad Café',
#   'latitud': 40.41237079206074,
#   'longitud': -3.708825691824009,
#   'direccion': 'C. Cava Alta, 13',
#   'distancia': 2069,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'American'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Bacoa',
#   'latitud': 40.416697729325435,
#   'longitud': -3.7016824585888597,
#   'direccion': 'Carrera de San Jerónimo, 3',
#   'distancia': 2781,
#   'postal': '28014',
#   'acron': 'ES',
#   'municipio': 'Madrid City Center',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Angus',
#   'latitud': 40.406993276447125,
#   'longitud': -3.725004542324277,
#   'direccion': 'Centro Comercial Art Deco',
#   'distancia': 1383,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d1df931735',
#   'nombre': 'Pecado Carnal',
#   'latitud': 40.411593,
#   'longitud': -3.695584,
#   'direccion': 'C. Fúcar',
#   'distancia': 2674,
#   'postal': '28014',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'BBQ'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Home Burger Bar',
#   'latitud': 40.42184030676169,
#   'longitud': -3.7055202641854845,
#   'direccion': 'C. Silva, 25',
#   'distancia': 3150,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Goiko Grill',
#   'latitud': 40.427658599033876,
#   'longitud': -3.7141252257911153,
#   'direccion': 'C. Princesa, 26',
#   'distancia': 3608,
#   'postal': '28008',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Goiko Grill',
#   'latitud': 40.41491161223453,
#   'longitud': -3.698489269116211,
#   'direccion': 'Calle Del Prado 15',
#   'distancia': 2775,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': None,
#   'ciudad': None,
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d147941735',
#   'nombre': "Tommy Mel's",
#   'latitud': 40.421333,
#   'longitud': -3.708569,
#   'direccion': 'Calle Gran Vía, 53',
#   'distancia': 3012,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Diner'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Anauco Gourmet',
#   'latitud': 40.42016065283576,
#   'longitud': -3.6991581405779623,
#   'direccion': 'Calle Reina 25',
#   'distancia': 3221,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d1d3941735',
#   'nombre': 'Viva Burger',
#   'latitud': 40.41263019326825,
#   'longitud': -3.7116827479753303,
#   'direccion': 'C. Costanilla de San Andrés, 16',
#   'distancia': 2009,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Vegetarian / Vegan'},
#  {'clave': '4bf58dd8d48988d14e941735',
#   'nombre': "Alfredo's Barbacoa",
#   'latitud': 40.421410275,
#   'longitud': -3.685863629,
#   'direccion': 'Calle Lagasca, 5, LOC',
#   'distancia': 4026,
#   'postal': '28001',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'American'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Five Guys',
#   'latitud': 40.4205257632994,
#   'longitud': -3.705539912285758,
#   'direccion': 'Calle Gran Via, 44',
#   'distancia': 3013,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'New York Burger',
#   'latitud': 40.42212085931879,
#   'longitud': -3.6907109051907323,
#   'direccion': 'Calle de Recoletos, 4',
#   'distancia': 3813,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': "Bentley's",
#   'latitud': 40.419704696620165,
#   'longitud': -3.7064424018345,
#   'direccion': 'C. Preciados, 31',
#   'distancia': 2900,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d1c4941735',
#   'nombre': 'Fridays Peligros',
#   'latitud': 40.418118293081505,
#   'longitud': -3.6994219408556344,
#   'direccion': 'C. de la Virgen de los Peligros, 1',
#   'distancia': 3017,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Restaurant'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Steak Burger Bar',
#   'latitud': 40.409797926583366,
#   'longitud': -3.693670379662324,
#   'direccion': 'Atocha, 110',
#   'distancia': 2672,
#   'postal': '28012',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d164941735',
#   'nombre': 'Plaza de Antón Martín',
#   'latitud': 40.41245421442554,
#   'longitud': -3.6994664933938814,
#   'direccion': 'Pl. Antón Martín',
#   'distancia': 2512,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Plaza'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': "Bentley's",
#   'latitud': 40.421659936297836,
#   'longitud': -3.6829374682338556,
#   'direccion': 'C. Alcalá, 105',
#   'distancia': 4222,
#   'postal': '28009',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Steak Burger Bar',
#   'latitud': 40.425011715837506,
#   'longitud': -3.700787857475491,
#   'direccion': 'C. Fuencarral, 73',
#   'distancia': 3633,
#   'postal': '28010',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'TGB - The Good Burger',
#   'latitud': 40.41999097321446,
#   'longitud': -3.7006621410691167,
#   'direccion': 'Gran Vía, 22',
#   'distancia': 3141,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d1db931735',
#   'nombre': 'Taberna Rayuela',
#   'latitud': 40.41317891156541,
#   'longitud': -3.7134962971934686,
#   'direccion': 'C/ Morería, 8',
#   'distancia': 2026,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Tapas'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'Steak Burger Bar',
#   'latitud': 40.41885405761974,
#   'longitud': -3.699623124705167,
#   'direccion': 'C. Virgen de los Peligros, 10',
#   'distancia': 3077,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d1db931735',
#   'nombre': 'Museo del Jamón',
#   'latitud': 40.41665890338383,
#   'longitud': -3.7015152430287395,
#   'direccion': 'Carrera de San Jerónimo, 6',
#   'distancia': 2785,
#   'postal': '28014',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Tapas'},
#  {'clave': '4bf58dd8d48988d1c4941735',
#   'nombre': 'Taberna del Volapié',
#   'latitud': 40.41511671651124,
#   'longitud': -3.705627322196961,
#   'direccion': 'C. Prado, 10',
#   'distancia': 2463,
#   'postal': '28012',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Restaurant'},
#  {'clave': '4bf58dd8d48988d107941735',
#   'nombre': 'Los Porfiados',
#   'latitud': 40.410110365834385,
#   'longitud': -3.698907434582576,
#   'direccion': 'C. Buenavista, 18',
#   'distancia': 2355,
#   'postal': '28012',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Argentinian'},
#  {'clave': '4bf58dd8d48988d1c5941735',
#   'nombre': 'San Wich',
#   'latitud': 40.4250614980819,
#   'longitud': -3.7023402053018293,
#   'direccion': 'Espíritu Santo 3',
#   'distancia': 3584,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Sandwiches'},
#  {'clave': '4bf58dd8d48988d11b941735',
#   'nombre': "Jose's Bar",
#   'latitud': 40.38741983888793,
#   'longitud': -3.7011087354438392,
#   'direccion': 'C.  Marcelo Usera, 20',
#   'distancia': 1757,
#   'postal': '28026',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Pub'},
#  {'clave': '4bf58dd8d48988d116941735',
#   'nombre': 'Zombie Bar',
#   'latitud': 40.4232210043207,
#   'longitud': -3.704647908626003,
#   'direccion': 'C. Pez, 7',
#   'distancia': 3320,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Bar'},
#  {'clave': '4bf58dd8d48988d155941735',
#   'nombre': 'Naia Bistro',
#   'latitud': 40.41291095492994,
#   'longitud': -3.7116031277506236,
#   'direccion': 'Plaza de la Paja, 3',
#   'distancia': 2041,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Gastropub'},
#  {'clave': '4bf58dd8d48988d1e0931735',
#   'nombre': 'Churrería Los Artesanos 1902',
#   'latitud': 40.41758135061494,
#   'longitud': -3.7070293825992406,
#   'direccion': 'C. San Martín, 2',
#   'distancia': 2662,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Coffee Shop'},
#  {'clave': '4bf58dd8d48988d1c4941735',
#   'nombre': 'VIPS Príncipe Pío',
#   'latitud': 40.421855585349675,
#   'longitud': -3.7200566202925827,
#   'direccion': 'P. de la Florida, 2 (C.C. Príncipe Pío)',
#   'distancia': 2940,
#   'postal': '28008',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Restaurant'},
#  {'clave': '4bf58dd8d48988d1c5941735',
#   'nombre': 'Naif Sandwich & Bar',
#   'latitud': 40.42430407136737,
#   'longitud': -3.7019229620773473,
#   'direccion': 'Pl. San Ildefonso',
#   'distancia': 3521,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Sandwiches'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'TGB - The Good Burger',
#   'latitud': 40.43167330552131,
#   'longitud': -3.7051620098211,
#   'direccion': 'C. San Bernardo, 105',
#   'distancia': 4198,
#   'postal': '28015',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d14e941735',
#   'nombre': "Foster's Hollywood",
#   'latitud': 40.4053705303576,
#   'longitud': -3.7013422725394634,
#   'direccion': 'C/ Ronda de Valencia, 7',
#   'distancia': 1856,
#   'postal': '28012',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'American'},
#  {'clave': '4bf58dd8d48988d1d0941735',
#   'nombre': 'Mattiz Dulce&Salado',
#   'latitud': 40.390766591488386,
#   'longitud': -3.6917150471626266,
#   'direccion': 'C. Rodio, 4',
#   'distancia': 2367,
#   'postal': '28045',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Desserts'},
#  {'clave': '4bf58dd8d48988d1c4941735',
#   'nombre': 'La Pescadería',
#   'latitud': 40.42288279065907,
#   'longitud': -3.7032084227445803,
#   'direccion': 'C. Ballesta, 32',
#   'distancia': 3332,
#   'postal': '28004',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Restaurant'},
#  {'clave': '4bf58dd8d48988d16c941735',
#   'nombre': 'TGB Go',
#   'latitud': 40.42441880464517,
#   'longitud': -3.7021050207104333,
#   'direccion': 'Corredera Alta de San Pablo, 1',
#   'distancia': 3526,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Burgers'},
#  {'clave': '4bf58dd8d48988d14e941735',
#   'nombre': "Foster's Hollywood",
#   'latitud': 40.41801318705939,
#   'longitud': -3.709712486776967,
#   'direccion': 'Pl. de Isabel II, 3',
#   'distancia': 2630,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'American'},
#  {'clave': '4bf58dd8d48988d143941735',
#   'nombre': 'Carmencita',
#   'latitud': 40.426141864460845,
#   'longitud': -3.7073716314199663,
#   'direccion': 'C. San Vicente Ferrer, 51',
#   'distancia': 3554,
#   'postal': '28015',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Breakfast'},
#  {'clave': '4bf58dd8d48988d111941735',
#   'nombre': 'Miss Sushi',
#   'latitud': 40.414505,
#   'longitud': -3.700117,
#   'direccion': 'Calle del Prado 2',
#   'distancia': 2654,
#   'postal': '28014',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Japanese'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.401351215423524,
#   'longitud': -3.7040724421713116,
#   'direccion': 'P. de la Esperanza, 21',
#   'distancia': 1422,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d1df931735',
#   'nombre': 'Ribs',
#   'latitud': 40.419319738178785,
#   'longitud': -3.70410240394764,
#   'direccion': 'C. Abada, 8',
#   'distancia': 2940,
#   'postal': '28013',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'BBQ'},
#  {'clave': '4bf58dd8d48988d1ca941735',
#   'nombre': 'Pizza Emporio',
#   'latitud': 40.41972844614013,
#   'longitud': -3.706614525730406,
#   'direccion': 'Preciados',
#   'distancia': 2897,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': None,
#   'ciudad': None,
#   'pais': 'España',
#   'etiqueta': 'Pizza'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.41385457279063,
#   'longitud': -3.720681124578544,
#   'direccion': 'Paseo Virgen Del Puerto, 5',
#   'distancia': 2054,
#   'postal': '28005',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d116941735',
#   'nombre': 'Mama Teresa',
#   'latitud': 40.414860248565674,
#   'longitud': -3.7023067474365234,
#   'direccion': 'C. Espoz y Mina, 32',
#   'distancia': 2580,
#   'postal': '28012',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Bar'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.407169210460715,
#   'longitud': -3.674501583699681,
#   'direccion': 'Av. Mediterraneo, 24',
#   'distancia': 3987,
#   'postal': '28007',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.4121920882941,
#   'longitud': -3.693209850387824,
#   'direccion': 'P. del Prado, 26',
#   'distancia': 2869,
#   'postal': '28014',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d1df931735',
#   'nombre': 'Ribs',
#   'latitud': 40.36326109759938,
#   'longitud': -3.739033586305968,
#   'direccion': 'C.C. Islazul',
#   'distancia': 3967,
#   'postal': '28054',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'BBQ'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.42153475248662,
#   'longitud': -3.7195332107337458,
#   'direccion': 'C.C. Príncipe Pío',
#   'distancia': 2904,
#   'postal': '28008',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d150941735',
#   'nombre': 'Autogrill',
#   'latitud': 40.40641580182804,
#   'longitud': -3.6901199889281497,
#   'direccion': 'Estación de Atocha',
#   'distancia': 2731,
#   'postal': None,
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Spanish'},
#  {'clave': '4bf58dd8d48988d16e941735',
#   'nombre': 'Burger King',
#   'latitud': 40.43314517311146,
#   'longitud': -3.704362418972723,
#   'direccion': 'C. San Bernardo, 123',
#   'distancia': 4374,
#   'postal': '28015',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Fast Food'},
#  {'clave': '4bf58dd8d48988d1d2941735',
#   'nombre': 'Sushi Shop',
#   'latitud': 40.42089332633717,
#   'longitud': -3.6888131374485544,
#   'direccion': 'Calle Serrano 1',
#   'distancia': 3814,
#   'postal': '28001',
#   'acron': 'ES',
#   'municipio': 'Madrid',
#   'ciudad': 'Madrid',
#   'pais': 'España',
#   'etiqueta': 'Sushi'}]

# %%
parametros = {
            'client_id': tok1,
            'client_secret': tok2,
            'v': '20180323',
            'll': origen,
            'query': busqueda, 
            'limit': limite,
            'radius' : radio,    
            }

    
resp = requests.get(url= url_query, params = parametros).json()

data = resp.get("response").get("groups")[0].get("items")
